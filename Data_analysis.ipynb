# %% [markdown]
# <a href="https://colab.research.google.com/github/17prateek12/customer-behavior-predict-recommendation/blob/main/Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
url='https://raw.githubusercontent.com/17prateek12/customer-behavior-predict-recommendation/main/shopping_trends_updated.csv'

# %%
df=pd.read_csv(url)

# %%
df.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.nunique()
# Out:
# Customer ID               3900
# Age                         53
# Gender                       2
# Item Purchased              25
# Category                     4
# Purchase Amount (USD)       81
# Location                    50
# Size                         4
# Color                       25
# Season                       4
# Review Rating               26
# Subscription Status          2
# Shipping Type                6
# Discount Applied             2
# Promo Code Used              2
# Previous Purchases          50
# Payment Method               6
# Frequency of Purchases       7
# dtype: int64

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Category',hue='Season',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Item Purchased',hue='Season',data=df)
# Out:
# <Axes: xlabel='Item Purchased', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Item Purchased',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Item Purchased', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Frequency of Purchases',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Frequency of Purchases', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Category',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Payment Method',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Payment Method', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Payment Method',hue='Promo Code Used',data=df)
# Out:
# <Axes: xlabel='Payment Method', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Category',hue='Promo Code Used',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Item Purchased',hue='Promo Code Used',data=df)
# Out:
# <Axes: xlabel='Item Purchased', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Item Purchased',hue='Frequency of Purchases',data=df)
# Out:
# <Axes: xlabel='Item Purchased', ylabel='count'>

# %%
sns.barplot(x='Category',y='Review Rating',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Review Rating'>

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Age'].max()
# Out:
# 70

# %%
def age_group(age):
    if age < 25:
        return '18-24'
    elif age < 32:
        return '25-31'
    elif age < 39:
        return '32-38'
    elif age < 46:
        return '39-45'
    elif age < 53:
        return '46-52'
    elif age < 60:
        return '53-59'
    elif age < 66:
        return '60-65'
    else:
        return '66+'

# %%
df['AgeGroup'] = df['Age'].apply(age_group)

# %%
plt.figure(figsize = (20,8))
sns.countplot(x='AgeGroup',hue='Frequency of Purchases',data=df)
# Out:
# <Axes: xlabel='AgeGroup', ylabel='count'>

# %%
plt.figure(figsize = (20,8))
sns.countplot(x='AgeGroup',hue='Category',data=df)
# Out:
# <Axes: xlabel='AgeGroup', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize = (20,5))
ax=sns.countplot(x='AgeGroup',hue='Gender',data=df)

# %%
pd.crosstab(df['AgeGroup'],df['Category'])
# Out:
# Category  Accessories  Clothing  Footwear  Outerwear
# AgeGroup
# 18-24             142       236        61         47
# 25-31             176       243        87         36
# 32-38             172       221        75         38
# 39-45             174       225        66         43
# 46-52             141       224       115         47
# 53-59             171       242        85         45
# 60-65             144       184        64         41
# 66+               120       162        46         27

# %%
pd.crosstab(df['AgeGroup'],df['Gender'])
# Out:
# Gender    Female  Male
# AgeGroup
# 18-24        152   334
# 25-31        173   369
# 32-38        158   348
# 39-45        175   333
# 46-52        185   342
# 53-59        159   384
# 60-65        142   291
# 66+          104   251

# %%
pd.crosstab(df['Category'],df['Gender'])
# Out:
# Gender       Female  Male
# Category
# Accessories     392   848
# Clothing        556  1181
# Footwear        199   400
# Outerwear       101   223

# %%
pd.crosstab(df['Frequency of Purchases'],df['Item Purchased'])
# Out:
# Item Purchased          Backpack  Belt  Blouse  Boots  Coat  Dress  Gloves  \
# Frequency of Purchases
# Annually                      22    24      32     15    23     31      22
# Bi-Weekly                     21    24      31     23    20     20      23
# Every 3 Months                23    27      31     19    18     28      16
# Fortnightly                   22    19      20     25    27     20      21
# Monthly                       11    23      15      8    20     27      20
# Quarterly                     21    22      25     31    27     17      19
# Weekly                        23    22      17     23    26     23      19
#
# Item Purchased          Handbag  Hat  Hoodie  ...  Scarf  Shirt  Shoes  \
# Frequency of Purchases                        ...
# Annually                     21   21      15  ...     29     31     26
# Bi-Weekly                    20   17      27  ...     20     23     20
# Every 3 Months               31   20      23  ...     21     20     24
# ...

# %%
pd.crosstab(df['Frequency of Purchases'],df['AgeGroup'])
# Out:
# AgeGroup                18-24  25-31  32-38  39-45  46-52  53-59  60-65  66+
# Frequency of Purchases
# Annually                   78     54     86     78     58     87     81   50
# Bi-Weekly                  76     90     62     65     75     80     52   47
# Every 3 Months             81     86     78     70     82     74     56   57
# Fortnightly                68     79     70     74     79     68     63   41
# Monthly                    58     77     79     77     81     76     51   54
# Quarterly                  65     89     62     64     73     82     69   59
# Weekly                     60     67     69     80     79     76     61   47

# %%
pd.crosstab(df['Frequency of Purchases'],df['Category'])
# Out:
# Category                Accessories  Clothing  Footwear  Outerwear
# Frequency of Purchases
# Annually                        184       258        87         43
# Bi-Weekly                       180       247        80         40
# Every 3 Months                  180       265        92         47
# Fortnightly                     170       223        96         53
# Monthly                         171       263        75         44
# Quarterly                       189       239        83         52
# Weekly                          166       242        86         45

# %%
pd.crosstab(df['Item Purchased'],df['AgeGroup'])
# Out:
# AgeGroup        18-24  25-31  32-38  39-45  46-52  53-59  60-65  66+
# Item Purchased
# Backpack           12     25     25     26     12     14     19   10
# Belt               24     22     23     23     24     16     15   14
# Blouse             20     22     26     23     17     31     15   17
# Boots              12     18     25     14     29     19     16   11
# Coat               27     23     16     15     23     29     17   11
# Dress              25     19     15     24     24     20     21   18
# Gloves             21     20     23     13     16     18     15   14
# Handbag            20     18     13     18     19     29     17   19
# Hat                17     22     21     26     15     24     22    7
# Hoodie             15     19     22     30     17     10     16   22
# Jacket             20     13     22     28     24     16     24   16
# Jeans              15     20     11     22     14     21     11   10
# ...

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
correlation_with_target = df.corrwith(df['Frequency of Purchases'])
sns.heatmap(correlation_with_target.to_frame(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation with Frequency of Purchases')
plt.show()

# %%
updatedf=df.copy()

# %%
label_encoder = preprocessing.LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])
df['Item Purchased'] = label_encoder.fit_transform(df['Item Purchased'])
df['Category'] = label_encoder.fit_transform(df['Category'])
df['Location'] = label_encoder.fit_transform(df['Location'])
df['Size'] = label_encoder.fit_transform(df['Size'])
df['Color'] = label_encoder.fit_transform(df['Color'])
df['Season'] = label_encoder.fit_transform(df['Season'])
df['Subscription Status'] = label_encoder.fit_transform(df['Subscription Status'])
df['Shipping Type'] = label_encoder.fit_transform(df['Shipping Type'])
df['Discount Applied'] = label_encoder.fit_transform(df['Discount Applied'])
df['Promo Code Used'] = label_encoder.fit_transform(df['Promo Code Used'])
df['Payment Method'] = label_encoder.fit_transform(df['Payment Method'])
df['Frequency of Purchases'] = label_encoder.fit_transform(df['Frequency of Purchases'])
df['AgeGroup'] = label_encoder.fit_transform(df['AgeGroup'])
print(df)
# Out:
#       Customer ID  Age  Gender  Item Purchased  Category  \
# 0               1   55       1               2         1
# 1               2   19       1              23         1
# 2               3   50       1              11         1
# 3               4   21       1              14         2
# 4               5   45       1               2         1
# ...           ...  ...     ...             ...       ...
# 3895         3896   40       0               9         1
# 3896         3897   52       0               0         0
# 3897         3898   46       0               1         0
# 3898         3899   44       0              17         2
# 3899         3900   52       0               7         0
#
#       Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# 0                        53        16     0      7       3            3.1
# 1                        64        18     0     12       3            3.1
# ...

# %%
df.head()
# Out:
#    Customer ID  Age  Gender  Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55       1               2         1                     53
# 1            2   19       1              23         1                     64
# 2            3   50       1              11         1                     73
# 3            4   21       1              14         2                     90
# 4            5   45       1               2         1                     49
#
#    Location  Size  Color  Season  Review Rating  Subscription Status  \
# 0        16     0      7       3            3.1                    1
# 1        18     0     12       3            3.1                    1
# 2        20     2     12       1            3.1                    1
# 3        38     1     12       1            3.5                    1
# 4        36     1     21       1            2.7                    1
#
#    Shipping Type  Discount Applied  Promo Code Used  Previous Purchases  \
# ...

# %%
z_scores = (df - df.mean()) / df.std()
outliers = (np.abs(z_scores) > 3).any(axis=1)
outliers_data = df[outliers]
print("\nOutliers:\n", outliers_data)
# Out:
# Outliers:
#  Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Payment Method, Frequency of Purchases, AgeGroup]
# Index: []

# %%
X = df.drop(['Frequency of Purchases'], axis=1)

y = df['Frequency of Purchases']
print(y)
# Out:
# 0       3
# 1       3
# 2       6
# 3       6
# 4       0
#        ..
# 3895    6
# 3896    1
# 3897    5
# 3898    6
# 3899    5
# Name: Frequency of Purchases, Length: 3900, dtype: int64

# %%
model = RandomForestClassifier(n_estimators=110, max_depth=15, random_state=42)
model.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=110, random_state=42)

# %%
feature_importances = model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
print(feature_importance_df)
# Out:
#                   Feature  Importance
# 0             Customer ID    0.102887
# 5   Purchase Amount (USD)    0.094748
# 15     Previous Purchases    0.089549
# 6                Location    0.088948
# 8                   Color    0.083817
# 1                     Age    0.082371
# 10          Review Rating    0.080672
# 3          Item Purchased    0.078714
# 12          Shipping Type    0.052772
# 16         Payment Method    0.051869
# 17               AgeGroup    0.041781
# 9                  Season    0.041338
# 7                    Size    0.037723
# 4                Category    0.035175
# 2                  Gender    0.010436
# 14        Promo Code Used    0.009206
# 13       Discount Applied    0.009020
# 11    Subscription Status    0.008975

# %%
means=feature_importance_df.mean()
print(means)
# Out:
# Importance    0.055556
# dtype: float64
# <ipython-input-44-7ceeae94b929>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means=feature_importance_df.mean()

# %%
plt.figure(figsize=(18,10))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.title('Feature Importance for Item Purchase Prediction')
plt.show()

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
